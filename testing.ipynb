# %%
import pandas as pd
import torch 
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import pandas as pd
#       2 import torch
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_json("hf://datasets/DanFosing/public-domain-poetry/poems.json") # author,text,title

chars = sorted(list(set(df.text.str.cat()))) # unique characters in the text
vocab_size = len(chars)

stoi = { ch:i for i,ch in enumerate(chars) } # char to index
itos = { i:ch for i,ch in enumerate(chars) } # index to char
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_json("hf://datasets/DanFosing/public-domain-poetry/poems.json") # author,text,title
#       2
#       3 chars = sorted(list(set(df.text.str.cat()))) # unique characters in the text
#       4 vocab_size = len(chars)
#
# NameError: name 'pd' is not defined
